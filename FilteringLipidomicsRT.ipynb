# %%
import pandas as pd
import openpyxl

# %%
data = "Desktop/GerardoIga/2025/Celegans/CPLZ08292402-2_negative data.xlsx"

df = pd.read_excel(data)

# %%
df
# Out:
#         No               LipidIon          LipidGroup       Class  \
# 0        1     BiotinylPE(17:4)-H  BiotinylPE(17:4)-H  BiotinylPE
# 1        2     BiotinylPE(29:0)-H  BiotinylPE(29:0)-H  BiotinylPE
# 2        3     BiotinylPE(31:0)-H  BiotinylPE(31:0)-H  BiotinylPE
# 3        4     BiotinylPE(31:1)-H  BiotinylPE(31:1)-H  BiotinylPE
# 4        5     BiotinylPE(31:2)-H  BiotinylPE(31:2)-H  BiotinylPE
# ...    ...                    ...                 ...         ...
# 1298  1299       dMePE(40:8+OO)-H    dMePE(40:8+OO)-H       dMePE
# 1299  1300          dMePE(44:1)-H       dMePE(44:1)-H       dMePE
# 1300  1301  phSM(d19:0_16:1)+HCOO    phSM(d35:1)+HCOO        phSM
# 1301  1302  phSM(d19:0_18:1)+HCOO    phSM(d37:1)+HCOO        phSM
# 1302  1303       phSM(t41:0)+HCOO    phSM(t41:0)+HCOO        phSM
#
#          FattyAcid        FA1     FA2  FA3      CalcMz      ObsMz  ...  \
# 0           (17:4)     (17:4)     NaN  NaN  698.288181  698.28818  ...
# ...

# %%
df.shape
# Out:
# (1303, 33)

# %%
df_filt = df.loc[df.groupby('LipidIon')['Rt'].idxmax()]

# %%
df_filt.head(10)
# Out:
#     No            LipidIon          LipidGroup       Class FattyAcid     FA1  \
# 0    1  BiotinylPE(17:4)-H  BiotinylPE(17:4)-H  BiotinylPE    (17:4)  (17:4)
# 1    2  BiotinylPE(29:0)-H  BiotinylPE(29:0)-H  BiotinylPE    (29:0)  (29:0)
# 2    3  BiotinylPE(31:0)-H  BiotinylPE(31:0)-H  BiotinylPE    (31:0)  (31:0)
# 3    4  BiotinylPE(31:1)-H  BiotinylPE(31:1)-H  BiotinylPE    (31:1)  (31:1)
# 4    5  BiotinylPE(31:2)-H  BiotinylPE(31:2)-H  BiotinylPE    (31:2)  (31:2)
# 5    6  BiotinylPE(31:3)-H  BiotinylPE(31:3)-H  BiotinylPE    (31:3)  (31:3)
# 6    7  BiotinylPE(32:0)-H  BiotinylPE(32:0)-H  BiotinylPE    (32:0)  (32:0)
# 7    8  BiotinylPE(32:2)-H  BiotinylPE(32:2)-H  BiotinylPE    (32:2)  (32:2)
# 8    9  BiotinylPE(32:3)-H  BiotinylPE(32:3)-H  BiotinylPE    (32:3)  (32:3)
# 10  11  BiotinylPE(33:2)-H  BiotinylPE(33:2)-H  BiotinylPE    (33:2)  (33:2)
#
#     FA2  FA3      CalcMz      ObsMz  ...           ED3           LW1  \
# ...

# %%
#option2

df_sorted = df.sort_values(by='Rt', ascending=False)
df_filt2 = df_sorted.drop_duplicates(subset='LipidIon', keep='first')

# %%
df_filt.shape
# Out:
# (899, 33)

# %%
df_filt2.head()
# Out:
#         No            LipidIon        LipidGroup Class    FattyAcid      FA1  \
# 789    790  PC(12:0_12:0)+HCOO     PC(24:0)+HCOO    PC  (12:0_12:0)   (12:0)
# 340    341      LPC(12:0)+HCOO    LPC(12:0)+HCOO   LPC       (12:0)   (12:0)
# 441    442        LPE(18:0e)-H      LPE(18:0e)-H   LPE      (18:0e)  (18:0e)
# 1247  1248    SPHP(m22:1)+HCOO  SPHP(m22:1)+HCOO  SPHP      (m22:1)  (m22:1)
# 1232  1233    SPHP(m22:0)+HCOO  SPHP(m22:0)+HCOO  SPHP      (m22:0)  (m22:0)
#
#          FA2  FA3      CalcMz      ObsMz  ...          ED3          LW1  \
# 789   (12:0)  NaN  666.435161  666.43516  ...  365996.6970  140427.3036
# 340      NaN  NaN  484.268096  484.26810  ...   74615.5440   29470.6410
# 441      NaN  NaN  466.330301  466.33030  ...     261.5440   29805.9183
# 1247     NaN  NaN  464.314651  464.31465  ...  184096.9881  624886.5190
# 1232     NaN  NaN  466.330301  466.33030  ...    7017.4944  192504.1434
#
# ...

# %%
data2_positive = "Desktop/GerardoIga/2025/Celegans/CPLZ08292402-2_positive data.xlsx"

df2p = pd.read_excel(data2_positive)

df2p.head()
# Out:
#    No      LipidIon    LipidGroup Class FattyAcid     FA1  FA2  FA3  \
# 0   1  AcCa(15:0)+H  AcCa(15:0)+H  AcCa    (15:0)  (15:0)  NaN  NaN
# 1   2  AcCa(16:0)+H  AcCa(16:0)+H  AcCa    (16:0)  (16:0)  NaN  NaN
# 2   3  AcCa(17:1)+H  AcCa(17:1)+H  AcCa    (17:1)  (17:1)  NaN  NaN
# 3   4  AcCa(18:0)+H  AcCa(18:0)+H  AcCa    (18:0)  (18:0)  NaN  NaN
# 4   5  AcCa(18:0)+H  AcCa(18:0)+H  AcCa    (18:0)  (18:0)  NaN  NaN
#
#        CalcMz      ObsMz  ...          ED3          LW1           LW2  \
# 0  386.326485  386.32649  ...   644412.185    2321.1080  0.000000e+00
# 1  400.342135  400.34214  ...        0.000       0.0000  1.057062e+06
# 2  412.342135  412.34214  ...  1137681.002  163450.5650  0.000000e+00
# 3  428.373435  428.37344  ...  1509511.076   26130.6786  0.000000e+00
# 4  428.373435  428.37344  ...        0.000    3004.9536  4.654802e+06
#
#             LW3           LN1           LN2           LN3           LE1  \
# ...

# %%
df2p.shape
# Out:
# (2938, 33)

# %%
df2p_2 = df2p.loc[df.groupby('LipidIon')['Rt'].idxmax()]

# %%
df2p_2.shape
# Out:
# (899, 33)

# %%
df2p_2.head()
# Out:
#    No      LipidIon    LipidGroup Class FattyAcid     FA1  FA2  FA3  \
# 0   1  AcCa(15:0)+H  AcCa(15:0)+H  AcCa    (15:0)  (15:0)  NaN  NaN
# 1   2  AcCa(16:0)+H  AcCa(16:0)+H  AcCa    (16:0)  (16:0)  NaN  NaN
# 2   3  AcCa(17:1)+H  AcCa(17:1)+H  AcCa    (17:1)  (17:1)  NaN  NaN
# 3   4  AcCa(18:0)+H  AcCa(18:0)+H  AcCa    (18:0)  (18:0)  NaN  NaN
# 4   5  AcCa(18:0)+H  AcCa(18:0)+H  AcCa    (18:0)  (18:0)  NaN  NaN
#
#        CalcMz      ObsMz  ...          ED3          LW1           LW2  \
# 0  386.326485  386.32649  ...   644412.185    2321.1080  0.000000e+00
# 1  400.342135  400.34214  ...        0.000       0.0000  1.057062e+06
# 2  412.342135  412.34214  ...  1137681.002  163450.5650  0.000000e+00
# 3  428.373435  428.37344  ...  1509511.076   26130.6786  0.000000e+00
# 4  428.373435  428.37344  ...        0.000    3004.9536  4.654802e+06
#
#             LW3           LN1           LN2           LN3           LE1  \
# ...
